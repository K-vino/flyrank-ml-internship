# %% [markdown]
# <a href="https://colab.research.google.com/github/K-vino/flyrank-ml-internship/blob/main/work/notebooks/w02_ml_task_framing.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # ML-03 — Frame Your Lane as an ML Task
#
# [![Open In Colab](https://colab.research.google.com/assets/colab-badge.svg)](https://colab.research.google.com/github/K-vino/flyrank-ml-internship/blob/main/work/notebooks/w02_ml_task_framing.ipynb?flush_cache=true)
#
# This skeleton is yours to fill. Work the sections **in order** — each one has a one-line hint. Simple words, honest numbers.
#
# > Working with an AI assistant? Tell it to read `skills/README.md` first and load the one skill this assignment names on its card.

# %% [markdown]
# ## 1. My lane as an ML task (type)
#
# Task Type: Ranking
#
# Why: The goal is to rank webpages based on their priority for content refresh. Instead of simply classifying pages, the model produces an ordered list so the content team knows which pages should be updated first.

# %%
# This cell is for CODE (numbers, a query, a check).
# Write your text answer in the cell ABOVE this one — typing sentences here breaks Run All.

# %% [markdown]
# ## 2. Target or proxy
#
# Target/Proxy: Refresh Priority Score
#
# The target is a webpage's priority for content refresh. Since there is no direct label showing which pages should be refreshed, the priority is estimated using observed performance metrics such as impressions, CTR, average position, and trend direction.

# %%
# This cell is for CODE (numbers, a query, a check).
# Write your text answer in the cell ABOVE this one — typing sentences here breaks Run All.

# %% [markdown]
# ## 3. Success metric
#
# Success Metric: Precision@10
#
# A good model should correctly identify the webpages that most need refreshing. High Precision@10 means that most of the top-ranked pages are truly good candidates for content updates.

# %%
# This cell is for CODE (numbers, a query, a check).
# Write your text answer in the cell ABOVE this one — typing sentences here breaks Run All.

# %% [markdown]
# ## 4. The unit of analysis, as a real dataframe
#
# One row in the dataset represents one webpage.
#
# Each row contains search performance, traffic, engagement, and content information that can be used to determine whether the webpage should be refreshed.

# %%
# This cell is for CODE (numbers, a query, a check).
# Write your text answer in the cell ABOVE this one — typing sentences here breaks Run All.

# %%
# !git clone https://github.com/K-vino/flyrank-ml-internship.git
# %cd flyrank-ml-internship
# Out:
# Cloning into 'flyrank-ml-internship'...
# remote: Enumerating objects: 133, done.
# remote: Counting objects: 100% (133/133), done.
# remote: Compressing objects: 100% (89/89), done.
# remote: Total 133 (delta 46), reused 85 (delta 28), pack-reused 0 (from 0)
# Receiving objects: 100% (133/133), 1.85 MiB | 8.61 MiB/s, done.
# Resolving deltas: 100% (46/46), done.
# /content/flyrank-ml-internship

# %%
import pandas as pd

df = pd.read_csv("data/raw/content_refresh_anonymized.csv")

print("Number of webpages:", len(df))

df[[
    "content_id",
    "impressions_90d",
    "clicks_90d",
    "ctr",
    "avg_position",
    "trend_direction"
]].head()
# Out:
# Number of webpages: 30000
#              content_id  impressions_90d  clicks_90d   ctr  avg_position  \
# 0  content_304f48230142             3803          29  0.76          10.6
# 1  content_a1fb4e703a9e            15320           7  0.05          20.3
# 2  content_9aa793d4d895            12581          11  0.09          36.5
# 3  content_331d6c4de07b            11751          58  0.49           6.2
# 4  content_d99b7a2d90ca            19140          24  0.13          44.0
#
#   trend_direction
# 0            down
# 1            down
# 2            down
# 3          stable
# 4            down

# %% [markdown]
# ## 5. Why ML beats a fixed rule here
#
# A fixed rule cannot capture the complex relationship between multiple factors such as impressions, CTR, average position, trend direction, and engagement. Machine learning can learn patterns from historical data and provide better ranking recommendations than a simple if-statement.

# %%
# This cell is for CODE (numbers, a query, a check).
# Write your text answer in the cell ABOVE this one — typing sentences here breaks Run All.

# %% [markdown]
# ## Self-check
#
# Before you submit, confirm each line honestly:
#
# - [ ] Every section above is filled — markdown thinking AND the code that backs it
# - [ ] The notebook runs top to bottom with no errors (Runtime → Run all)
# - [ ] No client names, URLs, or private queries anywhere
# - [ ] My claims use careful words: observed, measured, directional, decision-support
# - [ ] Committed to my repo under `work/notebooks/` — then submit your repo URL on the card. Done.
