# %% [markdown]
# # ML-02 — Research Question and Provisional Lane
#
# [![Open In Colab](https://colab.research.google.com/assets/colab-badge.svg)](https://colab.research.google.com/github/K-vino/flyrank-ml-internship/blob/main/work/notebooks/w01_research_question.ipynb?flush_cache=true)
#
# This skeleton is yours to fill. Work the sections **in order** — each one has a one-line hint. Simple words, honest numbers.
#
# > Working with an AI assistant? Tell it to read `skills/README.md` first and load the one skill this assignment names on its card.

# %% [markdown]
# ## 1. My lane (or freestyle) and why
#
# Lane: Content Refresh Recommendation
#
# Why: I chose the Content Refresh Recommendation lane because I want to identify webpages that should be updated first. Updating the right pages can improve search performance while reducing unnecessary work.

# %%
# This cell is for CODE (numbers, a query, a check).
# Write your text answer in the cell ABOVE this one — typing sentences here breaks Run All.

# %% [markdown]
# 2. The question: decision, action, cost of a wrong call
#
# Research Question:
# Which webpages should be refreshed first to improve search performance?
#
# Decision:
# Help the content team decide which webpages should be updated first.
#
# Unit of Analysis:
# Individual webpage.
#
# Output:
# A ranked list of webpages that should be refreshed.
#
# Action:
# The content team updates the recommended webpages.
#
# Cost of a Wrong Recommendation:
# If the recommendation is wrong, time and effort may be wasted updating pages that do not need changes while important pages that require updates are ignored.

# %%
# This cell is for CODE (numbers, a query, a check).
# Write your text answer in the cell ABOVE this one — typing sentences here breaks Run All.

# %% [markdown]
# ## 3. Quick look at the data (2-3 real numbers)
#
# The starter dataset contains **30,000 webpages**.
#
# The average CTR is **0.5107**.
#
# The average impressions over the last 90 days are **5200.37**.
#
# The average search position is **16.34**.
#
# These numbers show that webpage performance varies, making it useful to prioritize which pages should be refreshed first.

# %%
# This cell is for CODE (numbers, a query, a check).
# Write your text answer in the cell ABOVE this one — typing sentences here breaks Run All.

# %%
# !pwd
# !find . -name "*.csv"
# Out:
# /content
# ./sample_data/california_housing_train.csv
# ./sample_data/mnist_train_small.csv
# ./sample_data/mnist_test.csv
# ./sample_data/california_housing_test.csv

# %%
# !git clone https://github.com/K-vino/flyrank-ml-internship.git
# %cd flyrank-ml-internship
# Out:
# Cloning into 'flyrank-ml-internship'...
# remote: Enumerating objects: 128, done.
# remote: Counting objects: 100% (128/128), done.
# remote: Compressing objects: 100% (84/84), done.
# remote: Total 128 (delta 42), reused 85 (delta 28), pack-reused 0 (from 0)
# Receiving objects: 100% (128/128), 1.85 MiB | 4.66 MiB/s, done.
# Resolving deltas: 100% (42/42), done.
# /content/flyrank-ml-internship

# %%
print(df.columns.tolist())
# Out:
# ['content_id', 'client_id', 'search_volume', 'competition', 'competition_level', 'cpc', 'content_type', 'main_intent', 'word_count', 'char_count', 'provider_used', 'model_used', 'impressions_90d', 'clicks_90d', 'pageviews_90d', 'sessions_90d', 'users_90d', 'engaged_sessions_90d', 'ai_sessions_90d', 'scroll_events_90d', 'days_with_impressions', 'days_with_sessions', 'impressions_last_30d', 'clicks_last_30d', 'sessions_last_30d', 'impressions_prev_30d', 'clicks_prev_30d', 'sessions_prev_30d', 'content_age_days', 'age_tier', 'age_tier_order', 'days_since_last_update', 'freshness_tier', 'word_count_tier', 'char_count_tier', 'ctr', 'avg_position', 'engagement_rate', 'scroll_rate', 'ai_traffic_pct', 'impression_tier', 'position_tier', 'trend_direction', 'trend_pct']

# %%
import pandas as pd

df = pd.read_csv("data/raw/content_refresh_anonymized.csv")

print("Number of webpages:", len(df))
print("Average CTR:", df["ctr"].mean())
print("Average Impressions:", df["impressions_90d"].mean())
print("Average Position:", df["avg_position"].mean())
# Out:
# Number of webpages: 30000
# Average CTR: 0.5107333333333334
# Average Impressions: 5200.3663
# Average Position: 16.342380000000002

# %% [markdown]
# ## 4. Careful words: what I can and can't claim
#
# This project provides decision-support based on historical search performance.
#
# The results should be treated as observed and directional rather than guaranteed outcomes.
#
# The recommendations can help prioritize webpages for review, but they cannot guarantee that refreshing a page will improve Google rankings or traffic.

# %%
# This cell is for CODE (numbers, a query, a check).
# Write your text answer in the cell ABOVE this one — typing sentences here breaks Run All.

# %% [markdown]
# ## Self-check
#
# Before you submit, confirm each line honestly:
#
# - [ ] Every section above is filled — markdown thinking AND the code that backs it
# - [ ] The notebook runs top to bottom with no errors (Runtime → Run all)
# - [ ] No client names, URLs, or private queries anywhere
# - [ ] My claims use careful words: observed, measured, directional, decision-support
# - [ ] Committed to my repo under `work/notebooks/` — then submit your repo URL on the card. Done.
